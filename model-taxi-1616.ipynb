# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "5"

import numpy as np
import torch
from torch import nn

SEED = 1337
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True

# %%
import  torch.nn.functional as F

SEED = 1337
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True

# -*- coding: utf-8 -*-
class FedNet(nn.Module):
    def __init__(self):
        super(FedNet, self).__init__()

        self.down_1 = nn.Sequential(
            nn.Conv2d(2, 64, 3, 2, 1, bias=False),
            nn.LeakyReLU(),
        )
        self.down_2 = nn.Sequential(
            nn.Conv2d(64, 64, 3, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(),
        )
        self.down_3 = nn.Sequential( 
            nn.Conv2d(64, 64, 3, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(),
        )
        
        self.time = nn.Sequential( 
            nn.Conv2d(192, 64, 1, 1, 0, bias=False),
#             nn.BatchNorm2d(64),
            nn.LeakyReLU(),
        )
        
        self.up_1 = nn.Sequential(
#             nn.Upsample(scale_factor=2),
            nn.Conv2d(64, 64, 3, 1, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(),
        )
        self.up_2 = nn.Sequential(
#             nn.Upsample(scale_factor=2),
            nn.Conv2d(64, 64, 3, 1, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(),
        )
        self.up_3 = nn.Sequential(    
#             nn.Upsample(scale_factor=2),
            nn.Conv2d(64, 2, 3, 1, 1, bias=False),
            
#             nn.Tanh()
        )
        
        self.attr = nn.Sequential(
            nn.Linear(8, 16),
            nn.Dropout(0.5),
            nn.LeakyReLU(),
            nn.Linear(16, 512),
            nn.Dropout(0.5),
        )
        
        self.init_weight()

    def init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.xavier_uniform_(m.weight.data)


    def forward(self, X, External):

        trend_1 = self.down_1(X[:, 0])
        period_1 = self.down_1(X[:, 1])
        closeness_1 = self.down_1(X[:, 2])
        
        time_1 = self.time(torch.cat([trend_1, period_1, closeness_1], dim=1)) # 8*8

        trend_2 = self.down_2(trend_1)
        period_2 = self.down_2(period_1)
        closeness_2 = self.down_2(closeness_1)
        
        time_2 = self.time(torch.cat([trend_2, period_2, closeness_2], dim=1)) # 4*4
        
        trend_3 = self.down_3(trend_2)
        period_3 = self.down_3(period_2)
        closeness_3 = self.down_3(closeness_2)
        
        time_3 = self.time(torch.cat([trend_3, period_3, closeness_3], dim=1)) # 2*2
        
        f = self.up_1(F.interpolate(time_3, scale_factor=2))
        
        f = self.up_2(F.interpolate((f+time_2), scale_factor=2))
                     
        f = self.up_3(F.interpolate((f+time_1), scale_factor=2))
        
        attr = self.attr(External)
        attr = attr.view(-1, 2, 16, 16)
        
        f = F.tanh(f+attr)
        
        return f

# %%
SEED = 1337
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True

# -*- coding: utf-8 -*-
import pickle
import math
import time
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

from torch import optim
from torch.utils.data import DataLoader

lr = 0.001
batch_size = 32
val_batch_size = 240
test_batch_size = 240

train_epochs = 100

x = open("data/taxi_021616_X.pkl", 'rb')
X = pickle.load(x)
x.close()

y = open("data/taxi_021616_Y.pkl", 'rb')
Y = pickle.load(y)
y.close()

external = open("data/taxi_021616_External.pkl", 'rb')
External = pickle.load(external)
external.close()

train_X = X[:-240]
train_Y = Y[:-240]
train_External = External[:-240]

test_X = X[-240:]
test_Y = Y[-240:]
test_External = External[-240:]

# %%
SEED = 1337
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True

x_test_cuda = torch.tensor(test_X, dtype=torch.float32).cuda()
y_test_cuda = torch.tensor(test_Y, dtype=torch.float32).cuda()
external_test_cuda = torch.tensor(test_External, dtype=torch.float32).cuda()

test = torch.utils.data.TensorDataset(x_test_cuda, y_test_cuda, external_test_cuda)

test_loader = torch.utils.data.DataLoader(test, batch_size=test_batch_size, shuffle=False)

train_best = np.zeros([len(train_Y), 2, 16 , 16])
test_best = np.zeros([len(test_Y), 2, 16 , 16])

splits = list(KFold(n_splits=5, shuffle=True, random_state=SEED).split(train_X, train_Y))

for i_fold, (train_idx, valid_idx) in enumerate(splits):
    x_train_fold = torch.tensor(train_X[train_idx], dtype=torch.float32).cuda()
    y_train_fold = torch.tensor(train_Y[train_idx], dtype=torch.float32).cuda()
    external_train_fold = torch.tensor(train_External[train_idx], dtype=torch.float32).cuda()

    x_val_fold = torch.tensor(train_X[valid_idx], dtype=torch.float32).cuda()
    y_val_fold = torch.tensor(train_Y[valid_idx], dtype=torch.float32).cuda()
    external_val_fold = torch.tensor(train_External[valid_idx], dtype=torch.float32).cuda()

    model = FedNet()

    model.cuda()
    
    optimizer = optim.Adam(model.parameters())
#     optimizer = optim.SGD(model.parameters(), lr=0.01)

    criterion = nn.MSELoss()
        
    train = torch.utils.data.TensorDataset(x_train_fold, y_train_fold, external_train_fold)
    valid = torch.utils.data.TensorDataset(x_val_fold, y_val_fold, external_val_fold)
    
    train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True)
    valid_loader = torch.utils.data.DataLoader(valid, batch_size=val_batch_size, shuffle=False)

    print(f'Fold {i_fold + 1}')
    
    history_loss = float("inf")

    for epoch in range(train_epochs):
        start_time = time.time()
        
        model.train()
        for i, (x_batch, y_batch, e_batch) in enumerate(train_loader, 1):
#             print(e_batch.shape)
            y_pred = model(x_batch, e_batch)
            loss = criterion(y_pred, y_batch)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
        model.eval()
        
        valid_preds_fold = np.zeros([len(y_val_fold), 2, 16 , 16])
        
        avg_val_loss = 0.0
        for i, (x_batch, y_batch, e_batch) in enumerate(valid_loader):
            y_pred = model(x_batch, e_batch).detach()
            valid_preds_fold[i * val_batch_size:(i+1) * val_batch_size] = y_pred.cpu().numpy()           
            avg_val_loss += criterion(y_pred, y_batch) / len(valid_loader)
        print(f'epoch_{epoch}: ', avg_val_loss**0.5*3057/2)
        
        if avg_val_loss < history_loss:
            history_loss = avg_val_loss
            torch.save(model, f'best_taxi_{i_fold + 1}.pkl')
    
    model = torch.load(f'best_taxi_{i_fold + 1}.pkl')
    model.eval()
    
    avg_val_loss = 0.0
    
    valid_preds_fold = np.zeros([len(y_val_fold), 2, 16, 16])

    for i, (x_batch, y_batch, e_batch) in enumerate(valid_loader):
        y_pred = model(x_batch, e_batch).detach()            
        valid_preds_fold[i * val_batch_size:(i+1) * val_batch_size] = y_pred.cpu().numpy() 
        
        avg_val_loss += criterion(y_pred[:, 0:2], y_batch[:, 0:2]) / len(valid_loader)
        
    print(f'val_{i_fold + 1}: ', avg_val_loss**0.5*3057/2)
    
    train_best[valid_idx] = valid_preds_fold
    
    test_preds_fold = np.zeros([len(test_Y), 2, 16, 16])

    for i, (x_batch, y_batch, e_batch) in enumerate(test_loader):
        y_pred = model(x_batch, e_batch).detach()
        test_preds_fold[i * test_batch_size:(i+1) * test_batch_size] = y_pred.cpu().numpy()           
    
    print(mean_squared_error(test_preds_fold[:, 0:2].reshape(-1, 1), test_Y[:, 0:2].reshape(-1, 1))**0.5*3057/2)
    
    test_best += test_preds_fold / 5
# Out:
# Fold 1
# /home/xiaosen/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# epoch_0:  tensor(80.3334, device='cuda:0')
# /home/xiaosen/anaconda3/lib/python3.6/site-packages/torch/serialization.py:241: UserWarning: Couldn't retrieve source code for container of type FedNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# epoch_1:  tensor(56.7564, device='cuda:0')
# epoch_2:  tensor(46.4651, device='cuda:0')
# epoch_3:  tensor(48.8438, device='cuda:0')
# epoch_4:  tensor(42.7173, device='cuda:0')
# epoch_5:  tensor(36.7795, device='cuda:0')
# epoch_6:  tensor(32.8105, device='cuda:0')
# epoch_7:  tensor(34.4719, device='cuda:0')
# epoch_8:  tensor(33.2999, device='cuda:0')
# epoch_9:  tensor(30.6960, device='cuda:0')
# epoch_10:  tensor(28.2777, device='cuda:0')
# epoch_11:  tensor(31.0094, device='cuda:0')
# epoch_12:  tensor(27.5106, device='cuda:0')
# epoch_13:  tensor(27.2931, device='cuda:0')
# epoch_14:  tensor(26.0506, device='cuda:0')
# epoch_15:  tensor(28.2808, device='cuda:0')
# epoch_16:  tensor(27.0407, device='cuda:0')
# epoch_17:  tensor(25.5309, device='cuda:0')
# epoch_18:  tensor(27.6500, device='cuda:0')
# epoch_19:  tensor(26.6046, device='cuda:0')
# epoch_20:  tensor(27.1248, device='cuda:0')
# epoch_21:  tensor(24.1082, device='cuda:0')
# epoch_22:  tensor(23.4357, device='cuda:0')
# epoch_23:  tensor(26.0136, device='cuda:0')
# epoch_24:  tensor(23.3013, device='cuda:0')
# epoch_25:  tensor(27.6989, device='cuda:0')
# epoch_26:  tensor(24.8857, device='cuda:0')
# epoch_27:  tensor(23.3364, device='cuda:0')
# epoch_28:  tensor(24.2042, device='cuda:0')
# epoch_29:  tensor(24.2778, device='cuda:0')
# epoch_30:  tensor(22.7332, device='cuda:0')
# epoch_31:  tensor(25.3953, device='cuda:0')
# epoch_32:  tensor(24.1729, device='cuda:0')
# epoch_33:  tensor(22.4483, device='cuda:0')
# epoch_34:  tensor(23.1400, device='cuda:0')
# epoch_35:  tensor(22.6925, device='cuda:0')
# epoch_36:  tensor(22.1250, device='cuda:0')
# epoch_37:  tensor(25.0359, device='cuda:0')
# epoch_38:  tensor(22.0211, device='cuda:0')
# epoch_39:  tensor(26.3201, device='cuda:0')
# epoch_40:  tensor(21.2773, device='cuda:0')
# epoch_41:  tensor(24.3258, device='cuda:0')
# epoch_42:  tensor(30.4977, device='cuda:0')
# epoch_43:  tensor(21.9062, device='cuda:0')
# epoch_44:  tensor(22.4442, device='cuda:0')
# epoch_45:  tensor(21.5323, device='cuda:0')
# epoch_46:  tensor(21.4538, device='cuda:0')
# epoch_47:  tensor(27.9201, device='cuda:0')
# epoch_48:  tensor(23.5469, device='cuda:0')
# epoch_49:  tensor(24.8141, device='cuda:0')
# epoch_50:  tensor(21.1148, device='cuda:0')
# epoch_51:  tensor(21.3806, device='cuda:0')
# epoch_52:  tensor(21.1791, device='cuda:0')
# epoch_53:  tensor(20.1611, device='cuda:0')
# epoch_54:  tensor(20.6589, device='cuda:0')
# epoch_55:  tensor(23.1136, device='cuda:0')
# epoch_56:  tensor(22.9219, device='cuda:0')
# epoch_57:  tensor(20.0300, device='cuda:0')
# epoch_58:  tensor(20.7313, device='cuda:0')
# epoch_59:  tensor(25.4181, device='cuda:0')
# epoch_60:  tensor(20.9610, device='cuda:0')
# epoch_61:  tensor(20.1045, device='cuda:0')
# epoch_62:  tensor(20.0647, device='cuda:0')
# epoch_63:  tensor(22.0658, device='cuda:0')
# epoch_64:  tensor(24.0697, device='cuda:0')
# epoch_65:  tensor(21.2483, device='cuda:0')
# epoch_66:  tensor(21.1670, device='cuda:0')
# epoch_67:  tensor(20.8096, device='cuda:0')
# epoch_68:  tensor(20.9558, device='cuda:0')
# epoch_69:  tensor(19.9211, device='cuda:0')
# epoch_70:  tensor(22.0441, device='cuda:0')
# epoch_71:  tensor(22.3942, device='cuda:0')
# epoch_72:  tensor(19.8589, device='cuda:0')
# epoch_73:  tensor(19.5967, device='cuda:0')
# epoch_74:  tensor(19.4378, device='cuda:0')
# epoch_75:  tensor(20.1619, device='cuda:0')
# epoch_76:  tensor(23.1329, device='cuda:0')
# epoch_77:  tensor(20.7091, device='cuda:0')
# epoch_78:  tensor(22.2893, device='cuda:0')
# epoch_79:  tensor(20.8605, device='cuda:0')
# epoch_80:  tensor(19.9072, device='cuda:0')
# epoch_81:  tensor(21.8712, device='cuda:0')
# epoch_82:  tensor(20.9357, device='cuda:0')
# epoch_83:  tensor(20.1215, device='cuda:0')
# epoch_84:  tensor(19.3622, device='cuda:0')
# epoch_85:  tensor(19.5464, device='cuda:0')
# epoch_86:  tensor(19.4934, device='cuda:0')
# epoch_87:  tensor(19.5878, device='cuda:0')
# epoch_88:  tensor(20.8560, device='cuda:0')
# epoch_89:  tensor(23.5614, device='cuda:0')
# epoch_90:  tensor(21.1885, device='cuda:0')
# epoch_91:  tensor(19.6551, device='cuda:0')
# epoch_92:  tensor(21.9600, device='cuda:0')
# epoch_93:  tensor(19.0712, device='cuda:0')
# epoch_94:  tensor(18.8212, device='cuda:0')
# epoch_95:  tensor(19.5674, device='cuda:0')
# epoch_96:  tensor(26.2806, device='cuda:0')
# epoch_97:  tensor(19.4974, device='cuda:0')
# epoch_98:  tensor(27.1135, device='cuda:0')
# epoch_99:  tensor(22.0050, device='cuda:0')
# val_1:  tensor(18.8212, device='cuda:0')
# 23.953497951128426
# Fold 2
# epoch_0:  tensor(84.9144, device='cuda:0')
# epoch_1:  tensor(64.7309, device='cuda:0')
# epoch_2:  tensor(50.3992, device='cuda:0')
# epoch_3:  tensor(45.4567, device='cuda:0')
# epoch_4:  tensor(40.4911, device='cuda:0')
# epoch_5:  tensor(38.2142, device='cuda:0')
# epoch_6:  tensor(37.0151, device='cuda:0')
# epoch_7:  tensor(41.5158, device='cuda:0')
# epoch_8:  tensor(41.4567, device='cuda:0')
# epoch_9:  tensor(34.3098, device='cuda:0')
# epoch_10:  tensor(33.4242, device='cuda:0')
# epoch_11:  tensor(32.7889, device='cuda:0')
# epoch_12:  tensor(33.0113, device='cuda:0')
# epoch_13:  tensor(31.4671, device='cuda:0')
# epoch_14:  tensor(30.2276, device='cuda:0')
# epoch_15:  tensor(29.3690, device='cuda:0')
# epoch_16:  tensor(28.3997, device='cuda:0')
# epoch_17:  tensor(29.1200, device='cuda:0')
# epoch_18:  tensor(26.6513, device='cuda:0')
# epoch_19:  tensor(28.2122, device='cuda:0')
# epoch_20:  tensor(30.3527, device='cuda:0')
# epoch_21:  tensor(27.4504, device='cuda:0')
# epoch_22:  tensor(27.6861, device='cuda:0')
# epoch_23:  tensor(28.8927, device='cuda:0')
# epoch_24:  tensor(26.7302, device='cuda:0')
# epoch_25:  tensor(33.1248, device='cuda:0')
# epoch_26:  tensor(24.9639, device='cuda:0')
# epoch_27:  tensor(37.7294, device='cuda:0')
# epoch_28:  tensor(26.2410, device='cuda:0')
# epoch_29:  tensor(28.2304, device='cuda:0')
# epoch_30:  tensor(28.4088, device='cuda:0')
# epoch_31:  tensor(30.5502, device='cuda:0')
# epoch_32:  tensor(28.0734, device='cuda:0')
# epoch_33:  tensor(24.7084, device='cuda:0')
# epoch_34:  tensor(25.9391, device='cuda:0')
# epoch_35:  tensor(27.9416, device='cuda:0')
# epoch_36:  tensor(27.3698, device='cuda:0')
# epoch_37:  tensor(23.3807, device='cuda:0')
# epoch_38:  tensor(23.3928, device='cuda:0')
# epoch_39:  tensor(24.0329, device='cuda:0')
# epoch_40:  tensor(23.0366, device='cuda:0')
# epoch_41:  tensor(23.4760, device='cuda:0')
# epoch_42:  tensor(24.8949, device='cuda:0')
# epoch_43:  tensor(26.7082, device='cuda:0')
# epoch_44:  tensor(22.5327, device='cuda:0')
# epoch_45:  tensor(24.5184, device='cuda:0')
# epoch_46:  tensor(25.0039, device='cuda:0')
# epoch_47:  tensor(22.4703, device='cuda:0')
# epoch_48:  tensor(27.7593, device='cuda:0')
# epoch_49:  tensor(27.4419, device='cuda:0')
# epoch_50:  tensor(24.8497, device='cuda:0')
# epoch_51:  tensor(30.1160, device='cuda:0')
# epoch_52:  tensor(27.1943, device='cuda:0')
# epoch_53:  tensor(26.4216, device='cuda:0')
# epoch_54:  tensor(21.9346, device='cuda:0')
# epoch_55:  tensor(22.7951, device='cuda:0')
# epoch_56:  tensor(21.8568, device='cuda:0')
# epoch_57:  tensor(22.7615, device='cuda:0')
# epoch_58:  tensor(21.9413, device='cuda:0')
# epoch_59:  tensor(23.1050, device='cuda:0')
# epoch_60:  tensor(26.9122, device='cuda:0')
# epoch_61:  tensor(22.0640, device='cuda:0')
# epoch_62:  tensor(23.0929, device='cuda:0')
# epoch_63:  tensor(21.1000, device='cuda:0')
# epoch_64:  tensor(25.8985, device='cuda:0')
# epoch_65:  tensor(23.6993, device='cuda:0')
# epoch_66:  tensor(24.5389, device='cuda:0')
# epoch_67:  tensor(21.4002, device='cuda:0')
# epoch_68:  tensor(22.4760, device='cuda:0')
# epoch_69:  tensor(26.6182, device='cuda:0')
# epoch_70:  tensor(22.6656, device='cuda:0')
# epoch_71:  tensor(22.5845, device='cuda:0')
# epoch_72:  tensor(23.2201, device='cuda:0')
# epoch_73:  tensor(21.5721, device='cuda:0')
# epoch_74:  tensor(21.0038, device='cuda:0')
# epoch_75:  tensor(20.9971, device='cuda:0')
# epoch_76:  tensor(22.1639, device='cuda:0')
# epoch_77:  tensor(20.2920, device='cuda:0')
# epoch_78:  tensor(21.1630, device='cuda:0')
# epoch_79:  tensor(21.1416, device='cuda:0')
# epoch_80:  tensor(20.5712, device='cuda:0')
# epoch_81:  tensor(22.1355, device='cuda:0')
# epoch_82:  tensor(20.8923, device='cuda:0')
# epoch_83:  tensor(22.7941, device='cuda:0')
# epoch_84:  tensor(21.0748, device='cuda:0')
# epoch_85:  tensor(21.2567, device='cuda:0')
# epoch_86:  tensor(21.0115, device='cuda:0')
# epoch_87:  tensor(20.8911, device='cuda:0')
# epoch_88:  tensor(21.5034, device='cuda:0')
# epoch_89:  tensor(20.2553, device='cuda:0')
# epoch_90:  tensor(19.4797, device='cuda:0')
# epoch_91:  tensor(24.0330, device='cuda:0')
# epoch_92:  tensor(19.4398, device='cuda:0')
# epoch_93:  tensor(19.8373, device='cuda:0')
# epoch_94:  tensor(19.4176, device='cuda:0')
# epoch_95:  tensor(19.8509, device='cuda:0')
# epoch_96:  tensor(20.5818, device='cuda:0')
# epoch_97:  tensor(21.0580, device='cuda:0')
# epoch_98:  tensor(21.3848, device='cuda:0')
# epoch_99:  tensor(20.5690, device='cuda:0')
# val_2:  tensor(19.4176, device='cuda:0')
# 23.780029344027938
# Fold 3
# epoch_0:  tensor(67.4266, device='cuda:0')
# epoch_1:  tensor(52.8270, device='cuda:0')
# epoch_2:  tensor(45.7070, device='cuda:0')
# epoch_3:  tensor(44.4604, device='cuda:0')
# epoch_4:  tensor(39.2676, device='cuda:0')
# epoch_5:  tensor(35.0735, device='cuda:0')
# epoch_6:  tensor(36.5181, device='cuda:0')
# epoch_7:  tensor(33.8159, device='cuda:0')
# epoch_8:  tensor(31.2622, device='cuda:0')
# epoch_9:  tensor(32.2116, device='cuda:0')
# epoch_10:  tensor(29.6018, device='cuda:0')
# epoch_11:  tensor(39.2536, device='cuda:0')
# epoch_12:  tensor(28.7574, device='cuda:0')
# epoch_13:  tensor(27.9146, device='cuda:0')
# epoch_14:  tensor(27.6852, device='cuda:0')
# epoch_15:  tensor(26.5207, device='cuda:0')
# epoch_16:  tensor(28.6467, device='cuda:0')
# epoch_17:  tensor(26.1964, device='cuda:0')
# epoch_18:  tensor(26.9094, device='cuda:0')
# epoch_19:  tensor(31.6581, device='cuda:0')
# epoch_20:  tensor(25.2924, device='cuda:0')
# epoch_21:  tensor(30.6208, device='cuda:0')
# epoch_22:  tensor(26.4738, device='cuda:0')
# epoch_23:  tensor(24.4076, device='cuda:0')
# epoch_24:  tensor(24.9631, device='cuda:0')
# epoch_25:  tensor(26.0570, device='cuda:0')
# epoch_26:  tensor(25.0536, device='cuda:0')
# epoch_27:  tensor(24.2221, device='cuda:0')
# epoch_28:  tensor(28.0987, device='cuda:0')
# epoch_29:  tensor(27.1312, device='cuda:0')
# epoch_30:  tensor(24.2270, device='cuda:0')
# epoch_31:  tensor(23.9619, device='cuda:0')
# epoch_32:  tensor(23.2911, device='cuda:0')
# epoch_33:  tensor(24.3745, device='cuda:0')
# epoch_34:  tensor(23.8214, device='cuda:0')
# epoch_35:  tensor(22.5969, device='cuda:0')
# epoch_36:  tensor(23.5606, device='cuda:0')
# epoch_37:  tensor(23.0517, device='cuda:0')
# epoch_38:  tensor(24.2945, device='cuda:0')
# epoch_39:  tensor(24.5362, device='cuda:0')
# epoch_40:  tensor(22.2167, device='cuda:0')
# epoch_41:  tensor(25.6091, device='cuda:0')
# epoch_42:  tensor(23.1804, device='cuda:0')
# epoch_43:  tensor(25.3069, device='cuda:0')
# epoch_44:  tensor(30.1967, device='cuda:0')
# epoch_45:  tensor(21.8206, device='cuda:0')
# epoch_46:  tensor(21.7936, device='cuda:0')
# epoch_47:  tensor(24.7992, device='cuda:0')
# epoch_48:  tensor(23.7220, device='cuda:0')
# epoch_49:  tensor(30.9342, device='cuda:0')
# epoch_50:  tensor(21.6753, device='cuda:0')
# epoch_51:  tensor(20.9345, device='cuda:0')
# epoch_52:  tensor(22.7359, device='cuda:0')
# epoch_53:  tensor(22.9373, device='cuda:0')
# epoch_54:  tensor(21.3188, device='cuda:0')
# epoch_55:  tensor(25.1044, device='cuda:0')
# epoch_56:  tensor(21.8755, device='cuda:0')
# epoch_57:  tensor(22.9281, device='cuda:0')
# epoch_58:  tensor(27.3937, device='cuda:0')
# epoch_59:  tensor(21.5849, device='cuda:0')
# epoch_60:  tensor(22.4470, device='cuda:0')
# epoch_61:  tensor(20.3326, device='cuda:0')
# epoch_62:  tensor(21.5915, device='cuda:0')
# epoch_63:  tensor(21.1540, device='cuda:0')
# epoch_64:  tensor(21.0129, device='cuda:0')
# epoch_65:  tensor(19.7943, device='cuda:0')
# epoch_66:  tensor(19.9127, device='cuda:0')
# epoch_67:  tensor(23.6317, device='cuda:0')
# epoch_68:  tensor(22.5800, device='cuda:0')
# epoch_69:  tensor(21.9227, device='cuda:0')
# epoch_70:  tensor(23.1748, device='cuda:0')
# epoch_71:  tensor(24.6217, device='cuda:0')
# epoch_72:  tensor(22.9223, device='cuda:0')
# epoch_73:  tensor(25.2581, device='cuda:0')
# epoch_74:  tensor(21.3442, device='cuda:0')
# epoch_75:  tensor(19.4242, device='cuda:0')
# epoch_76:  tensor(20.2975, device='cuda:0')
# epoch_77:  tensor(23.6402, device='cuda:0')
# epoch_78:  tensor(19.8467, device='cuda:0')
# epoch_79:  tensor(20.8211, device='cuda:0')
# epoch_80:  tensor(20.3488, device='cuda:0')
# epoch_81:  tensor(21.5606, device='cuda:0')
# epoch_82:  tensor(19.8909, device='cuda:0')
# epoch_83:  tensor(20.3405, device='cuda:0')
# epoch_84:  tensor(22.3105, device='cuda:0')
# epoch_85:  tensor(20.7499, device='cuda:0')
# epoch_86:  tensor(19.7586, device='cuda:0')
# epoch_87:  tensor(19.9228, device='cuda:0')
# epoch_88:  tensor(20.5142, device='cuda:0')
# epoch_89:  tensor(25.7463, device='cuda:0')
# epoch_90:  tensor(26.0125, device='cuda:0')
# epoch_91:  tensor(23.1296, device='cuda:0')
# epoch_92:  tensor(20.1243, device='cuda:0')
# epoch_93:  tensor(19.3049, device='cuda:0')
# epoch_94:  tensor(22.5536, device='cuda:0')
# epoch_95:  tensor(23.6834, device='cuda:0')
# epoch_96:  tensor(21.4864, device='cuda:0')
# epoch_97:  tensor(20.0079, device='cuda:0')
# epoch_98:  tensor(21.8836, device='cuda:0')
# epoch_99:  tensor(22.3986, device='cuda:0')
# val_3:  tensor(19.3049, device='cuda:0')
# 25.05598773099738
# Fold 4
# epoch_0:  tensor(75.4444, device='cuda:0')
# epoch_1:  tensor(56.3224, device='cuda:0')
# epoch_2:  tensor(46.9028, device='cuda:0')
# epoch_3:  tensor(44.0240, device='cuda:0')
# epoch_4:  tensor(38.5072, device='cuda:0')
# epoch_5:  tensor(39.9907, device='cuda:0')
# epoch_6:  tensor(50.5078, device='cuda:0')
# epoch_7:  tensor(34.8615, device='cuda:0')
# epoch_8:  tensor(31.5122, device='cuda:0')
# epoch_9:  tensor(30.5515, device='cuda:0')
# epoch_10:  tensor(29.4550, device='cuda:0')
# epoch_11:  tensor(33.5169, device='cuda:0')
# epoch_12:  tensor(28.4686, device='cuda:0')
# epoch_13:  tensor(29.2318, device='cuda:0')
# epoch_14:  tensor(27.5041, device='cuda:0')
# epoch_15:  tensor(35.0770, device='cuda:0')
# epoch_16:  tensor(27.8814, device='cuda:0')
# epoch_17:  tensor(31.5063, device='cuda:0')
# epoch_18:  tensor(47.1863, device='cuda:0')
# epoch_19:  tensor(29.8608, device='cuda:0')
# epoch_20:  tensor(28.0908, device='cuda:0')
# epoch_21:  tensor(26.3503, device='cuda:0')
# epoch_22:  tensor(24.3136, device='cuda:0')
# epoch_23:  tensor(32.3024, device='cuda:0')
# epoch_24:  tensor(25.8643, device='cuda:0')
# epoch_25:  tensor(29.6651, device='cuda:0')
# epoch_26:  tensor(24.3944, device='cuda:0')
# epoch_27:  tensor(25.4862, device='cuda:0')
# epoch_28:  tensor(24.3596, device='cuda:0')
# epoch_29:  tensor(23.8883, device='cuda:0')
# epoch_30:  tensor(23.1919, device='cuda:0')
# epoch_31:  tensor(25.5967, device='cuda:0')
# epoch_32:  tensor(27.0959, device='cuda:0')
# epoch_33:  tensor(22.9157, device='cuda:0')
# epoch_34:  tensor(29.5169, device='cuda:0')
# epoch_35:  tensor(24.8614, device='cuda:0')
# epoch_36:  tensor(22.0754, device='cuda:0')
# epoch_37:  tensor(23.9237, device='cuda:0')
# epoch_38:  tensor(25.6373, device='cuda:0')
# epoch_39:  tensor(30.9349, device='cuda:0')
# epoch_40:  tensor(22.3050, device='cuda:0')
# epoch_41:  tensor(26.2509, device='cuda:0')
# epoch_42:  tensor(27.4225, device='cuda:0')
# epoch_43:  tensor(22.1994, device='cuda:0')
# epoch_44:  tensor(22.2421, device='cuda:0')
# epoch_45:  tensor(21.1973, device='cuda:0')
# epoch_46:  tensor(30.5307, device='cuda:0')
# epoch_47:  tensor(23.8353, device='cuda:0')
# epoch_48:  tensor(21.2997, device='cuda:0')
# epoch_49:  tensor(29.4355, device='cuda:0')
# epoch_50:  tensor(20.7891, device='cuda:0')
# epoch_51:  tensor(24.4397, device='cuda:0')
# epoch_52:  tensor(22.0189, device='cuda:0')
# epoch_53:  tensor(22.7207, device='cuda:0')
# epoch_54:  tensor(21.5848, device='cuda:0')
# epoch_55:  tensor(21.3740, device='cuda:0')
# epoch_56:  tensor(20.8909, device='cuda:0')
# epoch_57:  tensor(23.9206, device='cuda:0')
# epoch_58:  tensor(21.6037, device='cuda:0')
# epoch_59:  tensor(20.8981, device='cuda:0')
# epoch_60:  tensor(23.0330, device='cuda:0')
# epoch_61:  tensor(25.8489, device='cuda:0')
# epoch_62:  tensor(20.1857, device='cuda:0')
# epoch_63:  tensor(21.2866, device='cuda:0')
# epoch_64:  tensor(27.1863, device='cuda:0')
# epoch_65:  tensor(21.6490, device='cuda:0')
# epoch_66:  tensor(21.0583, device='cuda:0')
# epoch_67:  tensor(20.4029, device='cuda:0')
# epoch_68:  tensor(20.8168, device='cuda:0')
# epoch_69:  tensor(27.5223, device='cuda:0')
# epoch_70:  tensor(26.6201, device='cuda:0')
# epoch_71:  tensor(19.7281, device='cuda:0')
# epoch_72:  tensor(19.8060, device='cuda:0')
# epoch_73:  tensor(25.6851, device='cuda:0')
# epoch_74:  tensor(20.3587, device='cuda:0')
# epoch_75:  tensor(22.4507, device='cuda:0')
# epoch_76:  tensor(20.1278, device='cuda:0')
# epoch_77:  tensor(23.6739, device='cuda:0')
# epoch_78:  tensor(19.8635, device='cuda:0')
# epoch_79:  tensor(20.6461, device='cuda:0')
# epoch_80:  tensor(20.1437, device='cuda:0')
# epoch_81:  tensor(20.6347, device='cuda:0')
# epoch_82:  tensor(20.2068, device='cuda:0')
# epoch_83:  tensor(20.2367, device='cuda:0')
# epoch_84:  tensor(19.8498, device='cuda:0')
# epoch_85:  tensor(20.0130, device='cuda:0')
# epoch_86:  tensor(20.3859, device='cuda:0')
# epoch_87:  tensor(20.4757, device='cuda:0')
# epoch_88:  tensor(19.3384, device='cuda:0')
# epoch_89:  tensor(19.9271, device='cuda:0')
# epoch_90:  tensor(20.2520, device='cuda:0')
# epoch_91:  tensor(23.2102, device='cuda:0')
# epoch_92:  tensor(20.6404, device='cuda:0')
# epoch_93:  tensor(19.9722, device='cuda:0')
# epoch_94:  tensor(19.0026, device='cuda:0')
# epoch_95:  tensor(21.3179, device='cuda:0')
# epoch_96:  tensor(19.7755, device='cuda:0')
# epoch_97:  tensor(20.0868, device='cuda:0')
# epoch_98:  tensor(21.2787, device='cuda:0')
# epoch_99:  tensor(19.1143, device='cuda:0')
# val_4:  tensor(19.0026, device='cuda:0')
# 23.16273661106715
# Fold 5
# epoch_0:  tensor(86.4895, device='cuda:0')
# epoch_1:  tensor(60.3251, device='cuda:0')
# epoch_2:  tensor(50.7767, device='cuda:0')
# epoch_3:  tensor(42.4543, device='cuda:0')
# epoch_4:  tensor(38.8985, device='cuda:0')
# epoch_5:  tensor(36.5073, device='cuda:0')
# epoch_6:  tensor(34.4997, device='cuda:0')
# epoch_7:  tensor(34.9914, device='cuda:0')
# epoch_8:  tensor(31.9961, device='cuda:0')
# epoch_9:  tensor(29.2255, device='cuda:0')
# epoch_10:  tensor(29.4731, device='cuda:0')
# epoch_11:  tensor(30.4908, device='cuda:0')
# epoch_12:  tensor(28.6134, device='cuda:0')
# epoch_13:  tensor(29.2191, device='cuda:0')
# epoch_14:  tensor(27.4171, device='cuda:0')
# epoch_15:  tensor(27.4466, device='cuda:0')
# epoch_16:  tensor(25.9281, device='cuda:0')
# epoch_17:  tensor(27.2722, device='cuda:0')
# epoch_18:  tensor(25.6947, device='cuda:0')
# epoch_19:  tensor(25.2771, device='cuda:0')
# epoch_20:  tensor(28.2768, device='cuda:0')
# epoch_21:  tensor(25.1206, device='cuda:0')
# epoch_22:  tensor(26.0384, device='cuda:0')
# epoch_23:  tensor(23.9537, device='cuda:0')
# epoch_24:  tensor(24.3947, device='cuda:0')
# epoch_25:  tensor(24.0747, device='cuda:0')
# epoch_26:  tensor(24.0838, device='cuda:0')
# epoch_27:  tensor(29.2402, device='cuda:0')
# epoch_28:  tensor(24.4599, device='cuda:0')
# epoch_29:  tensor(23.0558, device='cuda:0')
# epoch_30:  tensor(27.6203, device='cuda:0')
# epoch_31:  tensor(24.7082, device='cuda:0')
# epoch_32:  tensor(22.2305, device='cuda:0')
# epoch_33:  tensor(24.3883, device='cuda:0')
# epoch_34:  tensor(25.0354, device='cuda:0')
# epoch_35:  tensor(22.5961, device='cuda:0')
# epoch_36:  tensor(24.4747, device='cuda:0')
# epoch_37:  tensor(22.2525, device='cuda:0')
# epoch_38:  tensor(21.7140, device='cuda:0')
# epoch_39:  tensor(22.5532, device='cuda:0')
# epoch_40:  tensor(21.9239, device='cuda:0')
# epoch_41:  tensor(23.6118, device='cuda:0')
# epoch_42:  tensor(21.9506, device='cuda:0')
# epoch_43:  tensor(22.4633, device='cuda:0')
# epoch_44:  tensor(22.5990, device='cuda:0')
# epoch_45:  tensor(21.4380, device='cuda:0')
# epoch_46:  tensor(28.3789, device='cuda:0')
# epoch_47:  tensor(20.9967, device='cuda:0')
# epoch_48:  tensor(21.3036, device='cuda:0')
# epoch_49:  tensor(22.6460, device='cuda:0')
# epoch_50:  tensor(21.1101, device='cuda:0')
# epoch_51:  tensor(21.9297, device='cuda:0')
# epoch_52:  tensor(20.9808, device='cuda:0')
# epoch_53:  tensor(20.8488, device='cuda:0')
# epoch_54:  tensor(24.8996, device='cuda:0')
# epoch_55:  tensor(22.0381, device='cuda:0')
# epoch_56:  tensor(30.4998, device='cuda:0')
# epoch_57:  tensor(20.5396, device='cuda:0')
# epoch_58:  tensor(22.6896, device='cuda:0')
# epoch_59:  tensor(23.9923, device='cuda:0')
# epoch_60:  tensor(21.6250, device='cuda:0')
# epoch_61:  tensor(21.2995, device='cuda:0')
# epoch_62:  tensor(21.1912, device='cuda:0')
# epoch_63:  tensor(20.8714, device='cuda:0')
# epoch_64:  tensor(20.8777, device='cuda:0')
# epoch_65:  tensor(24.5848, device='cuda:0')
# epoch_66:  tensor(20.7105, device='cuda:0')
# epoch_67:  tensor(20.5838, device='cuda:0')
# epoch_68:  tensor(20.0465, device='cuda:0')
# epoch_69:  tensor(20.0546, device='cuda:0')
# epoch_70:  tensor(22.6551, device='cuda:0')
# epoch_71:  tensor(22.4628, device='cuda:0')
# epoch_72:  tensor(20.1130, device='cuda:0')
# epoch_73:  tensor(19.4130, device='cuda:0')
# epoch_74:  tensor(26.0900, device='cuda:0')
# epoch_75:  tensor(21.3799, device='cuda:0')
# epoch_76:  tensor(19.7617, device='cuda:0')
# epoch_77:  tensor(19.8872, device='cuda:0')
# epoch_78:  tensor(20.2160, device='cuda:0')
# epoch_79:  tensor(24.6357, device='cuda:0')
# epoch_80:  tensor(21.9679, device='cuda:0')
# epoch_81:  tensor(20.0225, device='cuda:0')
# epoch_82:  tensor(21.2177, device='cuda:0')
# epoch_83:  tensor(20.1018, device='cuda:0')
# epoch_84:  tensor(20.2725, device='cuda:0')
# epoch_85:  tensor(20.2026, device='cuda:0')
# epoch_86:  tensor(19.3000, device='cuda:0')
# epoch_87:  tensor(20.1978, device='cuda:0')
# epoch_88:  tensor(22.8422, device='cuda:0')
# epoch_89:  tensor(20.5842, device='cuda:0')
# epoch_90:  tensor(19.0702, device='cuda:0')
# epoch_91:  tensor(21.4213, device='cuda:0')
# epoch_92:  tensor(21.6452, device='cuda:0')
# epoch_93:  tensor(24.2655, device='cuda:0')
# epoch_94:  tensor(19.5358, device='cuda:0')
# epoch_95:  tensor(18.8073, device='cuda:0')
# epoch_96:  tensor(18.9580, device='cuda:0')
# epoch_97:  tensor(19.6159, device='cuda:0')
# epoch_98:  tensor(18.5252, device='cuda:0')
# epoch_99:  tensor(19.3081, device='cuda:0')
# val_5:  tensor(18.5252, device='cuda:0')
# 24.33872655554201

# %%
print(mean_squared_error(train_best.reshape(-1, 1), train_Y.reshape(-1, 1))**0.5*3057/2)
# Out:
# 18.944178461674714

# %%
print(mean_squared_error(test_best.reshape(-1, 1), test_Y.reshape(-1, 1))**0.5*3057/2)
# Out:
# 22.47175339422402

# %%
print(mean_squared_error(test_best[:, 0:2].reshape(-1, 1), test_Y[:, 0:2].reshape(-1, 1))**0.5*3057/2)
# Out:
# 22.471753418903532

# %%
import matplotlib.pyplot as plt
i = 12
j = 8

# %%
plt.plot(test_Y[:, 0, i, j], alpha=0.6)
plt.plot(test_best[:, 0, i, j])

# %%
plt.plot(train_Y[0:100, 0, i, j], alpha=0.6)
plt.plot(train_best[0:100, 0, i, j])
